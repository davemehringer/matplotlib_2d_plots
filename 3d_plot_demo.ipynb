# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from ipywidgets import interactive

# %%
f = lambda x, y: np.sin(x)*np.cos(y)

# %%
x = np.linspace(-2, 2, 50)
y = x.copy()
xm, ym = np.meshgrid(x, y)

# %%
fm = f(xm, ym)

# %%
plt.contour(xm, ym, fm)
plt.show()

# %%
fig = plt.figure(figsize=[12, 8])
ax = plt.gca(projection='3d')
ax.plot_surface(xm, ym, fm, cmap=cm.Spectral)
plt.show()
# Out:
# /tmp/ipykernel_564691/1042181953.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = plt.gca(projection='3d')

# %%
def plotter(E, A):
    fig = plt.figure(figsize=[12, 8])
    ax = plt.gca(projection='3d')
    ax.plot_surface(xm, ym, fm, cmap=cm.Spectral)
    ax.view_init(elev=E, azim=A)
    plt.show()

# %%
plotter(45,20)
# Out:
# /tmp/ipykernel_564691/1171632737.py:3: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = plt.gca(projection='3d')

# %%
iplot = interactive(plotter, E=(-90, 90, 5), A=(-90, 90, 5) )
iplot
# Out:
# interactive(children=(IntSlider(value=0, description='E', max=90, min=-90, step=5), IntSlider(value=0, descrip…
